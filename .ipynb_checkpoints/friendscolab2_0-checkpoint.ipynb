# %% [markdown]
# ## Importing libraries

# %%
import numpy as pandas
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# Out:
# /home/bhavesh/.local/lib/python3.6/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ## Reading csv

# %%
train=pd.read_csv("trainfr.csv")
test=pd.read_csv("testfr.csv")
#ans=pd.read_csv("sample_submissionfr.csv")

# %% [markdown]
# ### Dropping unecessary columns

# %%
train.drop(["Person A","Person B"],axis=1,inplace=True)
test.drop(["Person A","Person B"],axis=1,inplace=True)

# %%
combined=pd.concat([train,test],axis=0)

# %%
combined.drop(["ID"],axis=1,inplace=True)

# %%
combined.head(2)
# Out:
#    Years of Knowing  Interaction Duration Interaction Type  \
# 0          3.876560             13.035115            Class
# 1          2.836218              5.811429          At Work
#
#   Moon Phase During Interaction  Friends
# 0                Waning_Gibbous      1.0
# 1                Waxing_Cresent      0.0

# %%
combined["Interaction Type"].unique()
# Out:
# array(['Class', 'At Work', 'Over a Meal', 'Social_Media', 'Party',
#        'In Passing'], dtype=object)

# %%
sns.countplot(test["Interaction Type"])

# %%
figure=plt.figure(figsize=(12,10))
sns.countplot(x=combined["Moon Phase During Interaction"])

# %%
sns.distplot(combined["Years of Knowing"])

# %%
from scipy import stats

stats.chi2_contingency(combined["Interaction Type"].values)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-4e4074e5c881> in <module>
#       1 from scipy import stats
#       2
# ----> 3 stats.chi2_contingency(combined["Interaction Type"].values)
#
# ~/.local/lib/python3.6/site-packages/scipy/stats/contingency.py in chi2_contingency(observed, correction, lambda_)
#     242     """
#     243     observed = np.asarray(observed)
# --> 244     if np.any(observed < 0):
#     245         raise ValueError("All values in `observed` must be nonnegative.")
#     246     if observed.size == 0:
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %% [markdown]
# ## Concatinating train and test

# %%
train.shape
# Out:
# (54697, 8)

# %%
test.shape
# Out:
# (54697, 7)

# %%
combined.shape
# Out:
# (109394, 8)

# %% [markdown]
# ## Creating dummies

# %%
combined=pd.get_dummies(combined,columns=['Interaction Type','Moon Phase During Interaction','Person A','Person B'],drop_first=True)

# %%
combined.shape
# Out:
# (109394, 414)

# %%
combined.head()
# Out:
#    ID  Years of Knowing  ...  Person B_Ysabel  Person B_Zena
# 0   1          3.876560  ...                0              0
# 1   2          2.836218  ...                0              0
# 2   3          3.006119  ...                0              0
# 3   4          2.960067  ...                0              0
# 4   5          7.640688  ...                0              0
#
# [5 rows x 414 columns]

# %% [markdown]
# ## Splitting combined back to train and test

# %%
train=combined.iloc[:54697,:]

# %%
train.head()
# Out:
#    ID  Years of Knowing  ...  Person B_Ysabel  Person B_Zena
# 0   1          3.876560  ...                0              0
# 1   2          2.836218  ...                0              0
# 2   3          3.006119  ...                0              0
# 3   4          2.960067  ...                0              0
# 4   5          7.640688  ...                0              0
#
# [5 rows x 414 columns]

# %%
test=combined.iloc[54697:,:]

# %%
test.head()
# Out:
#    ID  Years of Knowing  ...  Person B_Ysabel  Person B_Zena
# 0   1          5.662542  ...                0              0
# 1   2          2.685942  ...                0              0
# 2   3          4.702476  ...                0              0
# 3   4          1.727021  ...                0              0
# 4   5          5.539269  ...                0              0
#
# [5 rows x 414 columns]

# %% [markdown]
# ## Dropping features

# %%
y=train["Friends"]

# %%
fulldata=[train,test]

# %%
droplist=['ID',"Friends"]
train=train.drop(droplist,axis=1)
test=test.drop(droplist,axis=1)

# %%
train.head()
# Out:
#    Years of Knowing  Interaction Duration  ...  Person B_Ysabel  Person B_Zena
# 0          3.876560             13.035115  ...                0              0
# 1          2.836218              5.811429  ...                0              0
# 2          3.006119              4.882863  ...                0              0
# 3          2.960067              9.274924  ...                0              0
# 4          7.640688              8.843167  ...                0              0
#
# [5 rows x 412 columns]

# %%
test.head()
# Out:
#    Years of Knowing  Interaction Duration  ...  Person B_Ysabel  Person B_Zena
# 0          5.662542             14.863449  ...                0              0
# 1          2.685942              3.002966  ...                0              0
# 2          4.702476             13.453554  ...                0              0
# 3          1.727021              3.780898  ...                0              0
# 4          5.539269             10.626012  ...                0              0
#
# [5 rows x 412 columns]

# %% [markdown]
# ## Splitting train into X_train and X_test

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(train,y, test_size=0.2, random_state=42)

# %% [markdown]
# ## Fitting XGBoost model

# %%
#XGBoost regressor
from xgboost import XGBClassifier
classifier=XGBClassifier()
classifier.fit(X_train,y_train)

# %%
# # Random forest
# from sklearn.ensemble import RandomForestClassifier
# classifier=RandomForestClassifier(n_estimators=10,criterion='entropy',random_state=0)
# classifier.fit(X_train,y_train)

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, y_pred)
# Out:
# array([[5095,  492],
#        [ 378, 4975]])

# %%
#Accuracy
from sklearn import metrics
print(metrics.accuracy_score(y_test,y_pred))
# Out:
# 0.9204753199268738

# %% [markdown]
# ## Predicting test set

# %%
y_p=classifier.predict(test)

# %%
ans['Friends']=y_p

# %%
ans["Friends"]=ans['Friends'].astype(int)

# %% [markdown]
# ## Creating solution csv

# %%
ans.to_csv('friends.csv',index=False)

# %%
ans.dtypes
# Out:
# ID         int64
# Friends    int64
# dtype: object

# %%
ans.head()
# Out:
#    ID  Friends
# 0   1        1
# 1   2        0
# 2   3        1
# 3   4        0
# 4   5        1
